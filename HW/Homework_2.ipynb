# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#-Homework-2-(Topics-5-7:-Groupby,-Merge,-Visualization)" data-toc-modified-id="-Homework-2-(Topics-5-7:-Groupby,-Merge,-Visualization)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><center> Homework 2 (Topics 5-7: Groupby, Merge, Visualization)</center></a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Task-0." data-toc-modified-id="Task-0.-1.0.0.1"><span class="toc-item-num">1.0.0.1&nbsp;&nbsp;</span>Task 0.</a></span></li><li><span><a href="#Task-1." data-toc-modified-id="Task-1.-1.0.0.2"><span class="toc-item-num">1.0.0.2&nbsp;&nbsp;</span>Task 1.</a></span></li><li><span><a href="#Task-2:" data-toc-modified-id="Task-2:-1.0.0.3"><span class="toc-item-num">1.0.0.3&nbsp;&nbsp;</span>Task 2:</a></span></li><li><span><a href="#Task-3:" data-toc-modified-id="Task-3:-1.0.0.4"><span class="toc-item-num">1.0.0.4&nbsp;&nbsp;</span>Task 3:</a></span></li><li><span><a href="#Task-4:" data-toc-modified-id="Task-4:-1.0.0.5"><span class="toc-item-num">1.0.0.5&nbsp;&nbsp;</span>Task 4:</a></span></li><li><span><a href="#Task-5:" data-toc-modified-id="Task-5:-1.0.0.6"><span class="toc-item-num">1.0.0.6&nbsp;&nbsp;</span>Task 5:</a></span></li><li><span><a href="#Вопросы:" data-toc-modified-id="Вопросы:-1.0.0.7"><span class="toc-item-num">1.0.0.7&nbsp;&nbsp;</span>Вопросы:</a></span></li><li><span><a href="#Task-6:" data-toc-modified-id="Task-6:-1.0.0.8"><span class="toc-item-num">1.0.0.8&nbsp;&nbsp;</span>Task 6:</a></span></li><li><span><a href="#Вопросы:" data-toc-modified-id="Вопросы:-1.0.0.9"><span class="toc-item-num">1.0.0.9&nbsp;&nbsp;</span>Вопросы:</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # <center> Homework 2 (Topics 5-7: Groupby, Merge, Visualization)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Ещё раз (как и в задании 1) считайте в переменные tr_mcc_codes, tr_types, transactions и customers_gender_train. В transactions опять считайте только первые 1000000 строк.

# %%
tr = pd.read_csv("data/transactions.csv", sep=',')
tr_mcc_codes = pd.read_csv("data/tr_mcc_codes.csv", sep=";")
tr_types = pd.read_csv("data/tr_types.csv", sep=";")
gender_train = pd.read_csv("data/gender_train.csv", sep=",")
tr = tr.head(1000000)
tr.head()
# Out:
#    customer_id tr_datetime  mcc_code  tr_type    amount term_id
# 0     39026145  0 10:23:26      4814     1030  -2245.92     NaN
# 1     39026145  1 10:19:29      6011     7010  56147.89     NaN
# 2     39026145  1 10:20:56      4829     2330 -56147.89     NaN
# 3     39026145  1 10:39:54      5499     1010  -1392.47     NaN
# 4     39026145  2 15:33:42      5499     1010   -920.83     NaN

# %% [markdown]
# #### Task 0.
# Соедините transactions с всеми остальными таблицами (tr_mcc_codes, tr_types, gender_train). Причём с customers_gender_train необходимо смёрджиться с помощью left join, а с оставшимися датафреймами - через inner.
# После получения результата таблицы gender_train, tr_types, tr_mcc_codes можно удалить. В результате соединения датафреймов должно получиться 999584 строки.

# %%
r1 = pd.merge(tr, gender_train[['customer_id','gender']], on='customer_id', how='left')
r2 = pd.merge(r1, tr_mcc_codes, on='mcc_code', how='inner')
r3 = pd.merge(r2, tr_types, on='tr_type', how='inner')
table = r3
table
# Out:
#         customer_id   tr_datetime  mcc_code  tr_type      amount term_id  \
# 0          39026145    0 10:23:26      4814     1030    -2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030    -5614.79     NaN
# 2          39026145    8 07:06:10      4814     1030    -1122.96     NaN
# 3          39026145   11 08:49:03      4814     1030    -2245.92     NaN
# 4          39026145   11 14:12:08      4814     1030    -2245.92     NaN
# ...             ...           ...       ...      ...         ...     ...
# 999579     36837532   18 23:38:60      3000     6000  1297824.89     NaN
# 999580      6808459  206 19:00:10      3000     6000   124693.24     NaN
# 999581     83759123   90 22:40:57      3000     6000   218976.79     NaN
# 999582     89619970  104 23:39:35      3000     6000   408307.49     NaN
# 999583     89619970  105 23:38:49      3000     6000   204153.74     NaN
#
#         gender                                    mcc_description  \
# 0          1.0  Звонки с использованием телефонов, считывающих...
# 1          1.0  Звонки с использованием телефонов, считывающих...
# 2          1.0  Звонки с использованием телефонов, считывающих...
# 3          1.0  Звонки с использованием телефонов, считывающих...
# 4          1.0  Звонки с использованием телефонов, считывающих...
# ...        ...                                                ...
# 999579     NaN                            Авиалинии, авиакомпании
# 999580     NaN                            Авиалинии, авиакомпании
# 999581     NaN                            Авиалинии, авиакомпании
# 999582     NaN                            Авиалинии, авиакомпании
# 999583     NaN                            Авиалинии, авиакомпании
#
#                         tr_description
# 0       Оплата услуги. Банкоматы СБ РФ
# 1       Оплата услуги. Банкоматы СБ РФ
# 2       Оплата услуги. Банкоматы СБ РФ
# 3       Оплата услуги. Банкоматы СБ РФ
# 4       Оплата услуги. Банкоматы СБ РФ
# ...                                ...
# 999579      Возврат  покупки. ТУ СБ РФ
# 999580      Возврат  покупки. ТУ СБ РФ
# 999581      Возврат  покупки. ТУ СБ РФ
# 999582      Возврат  покупки. ТУ СБ РФ
# 999583      Возврат  покупки. ТУ СБ РФ
#
# [999584 rows x 9 columns]

# %% [markdown]
# #### Task 1.
# 1. Определите модуль разницы между средними тратами женщин и мужчин (трата - отрицательное значение amount). (*)
#
# Выведите ответ в виде вещественного числа, округлённого до двух знаков после запятой, отделив дробную часть точкой в формате "123.45"
#
# ##### Пояснения:
# (\*) Если в результате для мужчин получились значения [-1,-3,-5], а для женщин [-1,-2,-3],
# то модуль разницы между средними арифметическими -3 и -2 будет равен 1.
#
# (\**) Обратите внимание, что для вычисления модуля разности точных знаний о том,
# какой класc относится к мужчинам, а какой - к женщинам, пока не требуется.
#
# (\***) Округление не нужно производить отдельно по средним тратам женщин и мужчин, а только в самом конце, когда получите значение модуля разницы трат.

# %%
table1 = table[table.amount<0]
x1 = (table1[table1.gender == 1.0]).amount.mean()
x2 = (table1[table1.gender == 0.0]).amount.mean()
result = abs(x2-x1)
result
# Out:
# 32718.05492021877

# %% [markdown]
# #### Task 2:
# 1. Создайте новый столбец - mcc_code+tr_type, сконкатенировав значения из соответствующих столбцов. (\*)
# 2. Оставьте только наблюдения с отрицательным значением amount. Посчитайте дисперсию по категориям получившегося столбца mcc_code+tr_type, в которых количество наблюдений >= 10.
# 3. Определите отношение максимальной дисперсии к минимальной.
#
# Выведите ответ в виде вещественного числа, округлённого до ближайшего целого в формате "123456" без дробной части.
#
# ##### Пояснения:
# (\*) Для конкатенации значений в столбцах можно использовать метод .astype(str) для серии и складывать соответствующие серии. Либо же применять apply к строкам датафрейма, прописывая логику преобразования и конкатенации значений внутри.
#
# (\**) Для одновременного подсчета количества наблюдений и дисперсии по категориям можно воспользоваться функцией .agg()

# %%
table2 = table.copy()
table2['mcc_type'] = table2['mcc_code'].astype(str) + table2['tr_type'].astype(str)
table2 = table2[table2.amount < 0]
table2
# Out:
#         customer_id   tr_datetime  mcc_code  tr_type    amount term_id  \
# 0          39026145    0 10:23:26      4814     1030  -2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030  -5614.79     NaN
# 2          39026145    8 07:06:10      4814     1030  -1122.96     NaN
# 3          39026145   11 08:49:03      4814     1030  -2245.92     NaN
# 4          39026145   11 14:12:08      4814     1030  -2245.92     NaN
# ...             ...           ...       ...      ...       ...     ...
# 999562      4181983  336 11:41:14      4900     2320  -3571.01  888918
# 999563     14892960   61 12:28:52      4900     2320   -718.69     NaN
# 999564     14892960   61 12:30:47      4900     2320 -35575.31     NaN
# 999565     62693770  333 19:26:37      4900     2320 -72385.87  888917
# 999566     62693770  333 19:27:26      4900     2320  -4491.83  888917
#
#         gender                                    mcc_description  \
# 0          1.0  Звонки с использованием телефонов, считывающих...
# 1          1.0  Звонки с использованием телефонов, считывающих...
# 2          1.0  Звонки с использованием телефонов, считывающих...
# 3          1.0  Звонки с использованием телефонов, считывающих...
# 4          1.0  Звонки с использованием телефонов, считывающих...
# ...        ...                                                ...
# 999562     NaN  Коммунальные услуги — электричество, газ, сани...
# 999563     NaN  Коммунальные услуги — электричество, газ, сани...
# 999564     NaN  Коммунальные услуги — электричество, газ, сани...
# 999565     0.0  Коммунальные услуги — электричество, газ, сани...
# 999566     0.0  Коммунальные услуги — электричество, газ, сани...
#
#                                         tr_description  mcc_type
# 0                       Оплата услуги. Банкоматы СБ РФ  48141030
# 1                       Оплата услуги. Банкоматы СБ РФ  48141030
# 2                       Оплата услуги. Банкоматы СБ РФ  48141030
# 3                       Оплата услуги. Банкоматы СБ РФ  48141030
# 4                       Оплата услуги. Банкоматы СБ РФ  48141030
# ...                                                ...       ...
# 999562  Безналичный перевод денежных средств через POS  49002320
# 999563  Безналичный перевод денежных средств через POS  49002320
# 999564  Безналичный перевод денежных средств через POS  49002320
# 999565  Безналичный перевод денежных средств через POS  49002320
# 999566  Безналичный перевод денежных средств через POS  49002320
#
# [768645 rows x 10 columns]

# %%
tr = tr.groupby(['mcc_code+tr_type']).filter(lambda x: len(x) >= 10)
tr
# Out:
#         customer_id   tr_datetime  mcc_code  tr_type    amount term_id  \
# 0          39026145    0 10:23:26      4814     1030  -2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030  -5614.79     NaN
# 2          39026145    8 07:06:10      4814     1030  -1122.96     NaN
# 3          39026145   11 08:49:03      4814     1030  -2245.92     NaN
# 4          39026145   11 14:12:08      4814     1030  -2245.92     NaN
# ...             ...           ...       ...      ...       ...     ...
# 999482     93803703   25 05:57:54      6010     4020  -7686.20     NaN
# 999483     14552261    6 15:40:00      6010     4020  -4469.37     NaN
# 999484     24753950  137 08:31:27      6010     4020 -44469.13     NaN
# 999485     65933176  325 14:46:51      6010     4020 -18191.92  172815
# 999486     90641486  209 14:42:01      6010     4020  -8759.07  890801
#
#                                            tr_description mcc_code+tr_type
# 0                          Оплата услуги. Банкоматы СБ РФ         48141030
# 1                          Оплата услуги. Банкоматы СБ РФ         48141030
# 2                          Оплата услуги. Банкоматы СБ РФ         48141030
# 3                          Оплата услуги. Банкоматы СБ РФ         48141030
# 4                          Оплата услуги. Банкоматы СБ РФ         48141030
# ...                                                   ...              ...
# 999482  Плата за получение наличных через POS в Сбербанке         60104020
# 999483  Плата за получение наличных через POS в Сбербанке         60104020
# 999484  Плата за получение наличных через POS в Сбербанке         60104020
# 999485  Плата за получение наличных через POS в Сбербанке         60104020
# 999486  Плата за получение наличных через POS в Сбербанке         60104020
#
# [767785 rows x 8 columns]

# %%
f = lambda x: x.tr_datetime.count() >= 10
gb = table2.groupby('mcc_type').filter(f)
gb = gb.groupby('mcc_type').amount.agg([lambda x: np.var(x)])
gb = gb.rename(columns={'<lambda>':'var_'})
result = gb.var_.max() / gb.var_.min() 
result
# Out:
# 8655155.499139175

# %% [markdown]
# Ответ: 8655155.49

# %% [markdown]
# #### Task 3:
# 1. По всем типам транзакций рассчитайте максимальную сумму прихода на карту (из строго положительных сумм по столбцу amount) отдельно для мужчин и женщин (назовите ее "max_income"). Оставьте по 5 транзакций для мужчин и для женщин, наименьших среди всех транзакций по полученным значениям "max_income". (\*)
# 2. Выделите среди них те, которые встречаются одновременно и у мужчин, и у женщин:
#     - 1) Покупка. POS ТУ СБ РФ
#     - 2) Списание после проведения претензионной работы
#     - 3) Плата за получение наличных. Россия
#     - 4) Перевод на карту/ с карты через АТМ (со взиманием комиссии с отправителя) по счету в овердрафте
#     - 5) Плата за получение наличных в АТМ. Россия
#     - 6) Наличные. Зарубеж. банк
#     - 7) Возврат покупки. POS ТУ Россия
#
# ##### Пояснения:
# (\*) Если максимальные суммы приходов по каким-то типам были равны [1,2,3,4,5,6,7,8], то 5 минимальных из них: [1,2,3,4,5]

# %%
table3 = table[table.amount > 0]
gb = table3.groupby(['tr_type', 'gender']).amount.agg(max_income='max')
gb
# Out:
#                 max_income
# tr_type gender
# 1010    0.0       24839.83
#         1.0       28803.87
# 1100    0.0     2097006.17
#         1.0      163727.26
# 1110    0.0      393035.26
# ...                    ...
# 7074    1.0     2245915.77
# 7075    0.0        6737.75
#         1.0      437953.58
# 8100    1.0       64682.37
# 8145    0.0      320145.86
#
# [72 rows x 1 columns]

# %%
gb=gb.reset_index()
gb0 = gb[gb.gender==0.0]
gb0=gb0.sort_values(by='max_income')
gb1 = gb[gb.gender==1.0]
gb1=gb1.sort_values(by='max_income')

# %%
gb0 = pd.merge(gb0, tr_types, on='tr_type', how='inner')
gb0.head()
# Out:
#    index  tr_type  gender  max_income  \
# 0     19     4051     0.0     1122.96
# 1     21     4110     0.0     2245.92
# 2     23     4210     0.0     2245.92
# 3     17     2370     0.0     2335.75
# 4     20     4100     0.0     5041.86
#
#                                       tr_description
# 0  Плата за перевод на карту (с карты) через АТМ ...
# 1          Плата за получение наличных в АТМ. Россия
# 2        Плата за получение наличных в АТМ. Зарубеж.
# 3  Списание с карты на карту по операции <перевод...
# 4                Плата за получение наличных. Россия

# %%
gb1 = pd.merge(gb1, tr_types, on='tr_type', how='inner')
gb1.head()
# Out:
#    index  tr_type  gender  max_income  \
# 0     22     4110     1.0     2245.92
# 1     12     2020     1.0     2245.92
# 2      1     1010     1.0    28803.87
# 3     70     8100     1.0    64682.37
# 4     25     6000     1.0    79280.83
#
#                                    tr_description
# 0       Плата за получение наличных в АТМ. Россия
# 1             Выдача наличных через POS Сбербанка
# 2                           Покупка. POS ТУ СБ РФ
# 3  Списание после проведения претензионной работы
# 4                      Возврат  покупки. ТУ СБ РФ

# %% [markdown]
# Ответ: №5

# %% [markdown]
# #### Task 4:
# 1. Выделите из поля tr_datetime относительный день tr_day (первое число до точного времени). (\*)
# 2. Отфильтруйте строки таким образом, чтобы оставить только те транзакции, у которых в соответствующий относительный день tr_day количество уникальных MCC кодов при транзакциях было больше 75 (можно воспользоваться функцией nunique())
# 3. Сгруппируйте полученный отфильтрованный датафрейм по MCC коду и полу, после чего, пронализировав результат, выберите верные варианты ответов ниже (\**):
#     - 1) gender == 0 - женщины, gender == 1 - мужчины
#     - 2) gender == 1 - женщины, gender == 0 - мужчины
#     - 3) Абсолютное значение медианы с типом "Флористика" (расходов/приходов) у мужчин выше той же медианы у женщин
#     - 4) Абсолютное значение медианы женских трат (расходов/приходов) на ценные бумаги выше мужских
#     - 5) Абсолютное значение медианы женских трат (расходов/приходов) в категории "Бары, коктейль-бары, дискотеки, ночные клубы и таверны — места продажи алкогольных напитков" ниже мужских
#
# ##### Пояснения:
# (\*) Для того, чтобы выделить всё, что стоит до первого пробела, можо использовать строковые методы для датафрейма - .str.split(), например. Либо же реализовывать логику выделения подстроки с помощью метода apply. <br>
# (\**) Понять, какой класс к какому типу транзакций (мужские/женские) относится можно, если поизучать типичные для мужчин/женщин категории и сравнить средние/медианы расходов и/или приходов в них.

# %%
date=table.tr_datetime.str.split(n=1,expand=True)
day = table.copy()
day["tr_day"] = date[0]
day
# Out:
#         customer_id   tr_datetime  mcc_code  tr_type      amount term_id  \
# 0          39026145    0 10:23:26      4814     1030    -2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030    -5614.79     NaN
# 2          39026145    8 07:06:10      4814     1030    -1122.96     NaN
# 3          39026145   11 08:49:03      4814     1030    -2245.92     NaN
# 4          39026145   11 14:12:08      4814     1030    -2245.92     NaN
# ...             ...           ...       ...      ...         ...     ...
# 999579     36837532   18 23:38:60      3000     6000  1297824.89     NaN
# 999580      6808459  206 19:00:10      3000     6000   124693.24     NaN
# 999581     83759123   90 22:40:57      3000     6000   218976.79     NaN
# 999582     89619970  104 23:39:35      3000     6000   408307.49     NaN
# 999583     89619970  105 23:38:49      3000     6000   204153.74     NaN
#
#         gender                                    mcc_description  \
# 0          1.0  Звонки с использованием телефонов, считывающих...
# 1          1.0  Звонки с использованием телефонов, считывающих...
# 2          1.0  Звонки с использованием телефонов, считывающих...
# 3          1.0  Звонки с использованием телефонов, считывающих...
# 4          1.0  Звонки с использованием телефонов, считывающих...
# ...        ...                                                ...
# 999579     NaN                            Авиалинии, авиакомпании
# 999580     NaN                            Авиалинии, авиакомпании
# 999581     NaN                            Авиалинии, авиакомпании
# 999582     NaN                            Авиалинии, авиакомпании
# 999583     NaN                            Авиалинии, авиакомпании
#
#                         tr_description tr_day
# 0       Оплата услуги. Банкоматы СБ РФ      0
# 1       Оплата услуги. Банкоматы СБ РФ      6
# 2       Оплата услуги. Банкоматы СБ РФ      8
# 3       Оплата услуги. Банкоматы СБ РФ     11
# 4       Оплата услуги. Банкоматы СБ РФ     11
# ...                                ...    ...
# 999579      Возврат  покупки. ТУ СБ РФ     18
# 999580      Возврат  покупки. ТУ СБ РФ    206
# 999581      Возврат  покупки. ТУ СБ РФ     90
# 999582      Возврат  покупки. ТУ СБ РФ    104
# 999583      Возврат  покупки. ТУ СБ РФ    105
#
# [999584 rows x 10 columns]

# %%
f = lambda x: x.mcc_code.nunique() >= 75
gb = day.groupby('tr_day').filter(f)
gb_in = gb[gb.amount > 0]
gb_out = gb[gb.amount < 0]
gb_abs = gb.copy();
gb_abs.amount = np.abs(gb_abs.amount)
gb_in = gb_in.groupby(['mcc_code', 'gender']).amount.agg(mean_in='mean',median_in=np.median)
gb_out = gb_out.groupby(['mcc_code', 'gender']).amount.agg(mean_out='mean',median_out=np.median)
gb_abs = gb_abs.groupby(['mcc_code', 'gender']).amount.agg(mean_amount='mean',median_amount=np.median)

gb_in=gb_in.reset_index()
gb_out=gb_out.reset_index()
gb_abs=gb_abs.reset_index()

# %%
gb_out_r = pd.merge(gb_out, tr_mcc_codes, on='mcc_code', how='inner')
gb_out_r = gb_out_r.sort_values(by='mean_out')
pd.options.display.max_rows = 100
gb_out_r.head(100)
# Out:
#      mcc_code  gender      mean_out   median_out  \
# 52       5039     1.0 -1.193251e+06  -238067.070
# 12       3351     1.0 -1.047592e+06 -1047591.690
# 237      6010     1.0 -8.526618e+05  -128017.200
# 329      8299     1.0 -7.619132e+05   -16844.370
# 148      5681     1.0 -7.441575e+05  -303872.400
# 2        1711     0.0 -6.748977e+05  -674897.690
# 334      8699     0.0 -5.211075e+05  -521107.480
# 199      5946     1.0 -4.778836e+05   -22122.270
# 250      7011     0.0 -4.594801e+05  -146321.415
# 32       4722     1.0 -4.467433e+05  -161363.880
# 122      5511     1.0 -4.361364e+05   -43301.255
# 9        3000     0.0 -4.320207e+05  -269621.515
# 236      6010     0.0 -4.093794e+05   -89836.630
# 30       4511     1.0 -3.589022e+05  -189851.415
# 318      8062     0.0 -3.468975e+05   -65646.320
# 167      5733     1.0 -3.453092e+05  -355651.205
# 10       3000     1.0 -3.407318e+05  -221020.570
# 31       4722     0.0 -3.344294e+05   -81734.490
# 21       4131     0.0 -3.077004e+05   -31038.560
# 147      5681     0.0 -2.810925e+05  -208870.170
# 44       4829     1.0 -2.767247e+05   -65131.560
# 218      5971     0.0 -2.702838e+05   -31756.575
# 247      6300     1.0 -2.681325e+05  -105434.970
# 246      6300     0.0 -2.626832e+05   -92082.550
# 207      5950     1.0 -2.622649e+05   -30611.830
# 29       4511     0.0 -2.541788e+05  -141075.405
# 54       5044     1.0 -2.463947e+05  -109600.690
# 195      5944     1.0 -2.452234e+05  -117461.390
# 219      5971     1.0 -2.368657e+05  -236865.730
# 251      7011     1.0 -2.333123e+05   -98752.920
# 249      6536     1.0 -2.072708e+05  -112295.790
# 203      5948     1.0 -1.941254e+05   -44918.320
# 278      7512     1.0 -1.938635e+05  -101066.210
# 14       3501     1.0 -1.933354e+05  -111011.685
# 131      5571     1.0 -1.922504e+05  -198202.065
# 154      5712     0.0 -1.906864e+05   -42205.250
# 124      5532     1.0 -1.762481e+05   -69168.590
# 320      8071     0.0 -1.738460e+05   -68186.000
# 64       5074     1.0 -1.718849e+05   -15721.410
# 151      5697     0.0 -1.717227e+05  -171722.720
# 239      6011     1.0 -1.714329e+05   -44918.320
# 134      5611     1.0 -1.699102e+05   -97528.895
# 155      5712     1.0 -1.658227e+05   -34654.480
# 13       3501     0.0 -1.650273e+05  -108093.900
# 326      8244     0.0 -1.605830e+05  -160582.980
# 132      5599     1.0 -1.584159e+05  -116805.590
# 78       5169     0.0 -1.569840e+05  -156984.010
# 194      5944     0.0 -1.552844e+05   -69847.980
# 68       5094     1.0 -1.526185e+05  -182592.950
# 161      5719     1.0 -1.460057e+05   -21513.630
# 123      5532     0.0 -1.459097e+05  -197640.590
# 43       4829     0.0 -1.448040e+05   -22459.160
# 308      7997     0.0 -1.384618e+05   -21560.790
# 324      8220     0.0 -1.347550e+05  -134754.950
# 328      8299     0.0 -1.309237e+05   -53901.980
# 322      8099     0.0 -1.283067e+05   -34946.450
# 163      5722     1.0 -1.253525e+05   -46220.950
# 60       5065     1.0 -1.235281e+05   -16414.610
# 325      8220     1.0 -1.217305e+05   -91633.360
# 63       5074     0.0 -1.197859e+05  -119785.920
# 315      8021     1.0 -1.186413e+05   -45367.500
# 23       4214     0.0 -1.178376e+05   -63784.005
# 314      8021     0.0 -1.168920e+05   -55024.935
# 160      5719     0.0 -1.163096e+05   -25828.030
# 281      7538     0.0 -1.161851e+05   -27281.360
# 53       5044     0.0 -1.153772e+05    -6737.750
# 282      7538     1.0 -1.135365e+05   -34003.165
# 86       5199     0.0 -1.122958e+05  -112295.790
# 335      8699     1.0 -1.110458e+05   -53271.775
# 101      5309     1.0 -1.106314e+05   -60302.840
# 79       5169     1.0 -1.083491e+05   -58488.590
# 238      6011     0.0 -1.070619e+05   -42672.400
# 133      5611     0.0 -1.047969e+05   -71487.500
# 313      8011     1.0 -1.041437e+05   -20213.240
# 93       5231     1.0 -1.031992e+05   -28242.390
# 95       5251     1.0 -1.028039e+05   -12981.390
# 215      5969     1.0 -1.020418e+05   -93070.975
# 293      7922     1.0 -9.956140e+04   -44918.320
# 100      5309     0.0 -9.654652e+04   -80179.190
# 309      7997     1.0 -9.491686e+04   -29196.910
# 150      5691     1.0 -9.259295e+04   -44895.860
# 317      8043     1.0 -9.055271e+04   -28309.770
# 121      5511     0.0 -8.990398e+04    -5727.090
# 162      5722     0.0 -8.958363e+04   -18865.690
# 323      8099     1.0 -8.897773e+04   -31442.820
# 164      5732     0.0 -8.744277e+04   -29376.580
# 143      5655     0.0 -8.729145e+04   -53228.200
# 165      5732     1.0 -8.727977e+04   -29646.090
# 340      9311     0.0 -8.645114e+04   -16429.770
# 11       3351     0.0 -8.495985e+04   -84959.850
# 135      5621     0.0 -8.431802e+04   -44390.530
# 153      5699     1.0 -8.419586e+04   -42110.920
# 5        1799     0.0 -8.148931e+04   -45704.390
# 265      7299     0.0 -8.011790e+04   -40089.600
# 136      5621     1.0 -7.961283e+04   -42268.130
# 166      5733     0.0 -7.928083e+04   -79280.830
# 321      8071     1.0 -7.911238e+04   -63447.120
# 311      7999     1.0 -7.775535e+04   -29196.910
# 202      5948     0.0 -7.747670e+04   -47164.230
# 56       5045     1.0 -7.723213e+04   -48736.370
#
#                                        mcc_description
# 52   Строительные материалы — нигде более не класси...
# 12                     Агентства по аренде автомобилей
# 237   Финансовые институты — снятие наличности вручную
# 329                             Образовательные услуги
# 148             Изготовление и продажа меховых изделий
# 2    Генеральные подрядчики по вентиляции, теплосна...
# 334  Организации, членства, нигде ранее не классифи...
# 199           Магазины фотооборудования и фотоприборов
# 250   Отели, мотели, базы отдыха, сервисы бронирования
# 32    Туристические агентства и организаторы экскурсий
# 122  Легковой и грузовой транспорт — продажа, серви...
# 9                              Авиалинии, авиакомпании
# 236   Финансовые институты — снятие наличности вручную
# 30   Авиалинии, авиакомпании, нигде более не класси...
# 318                                           Больницы
# 167  Продажа музыкальных инструментов, фортепиано, нот
# 10                             Авиалинии, авиакомпании
# 31    Туристические агентства и организаторы экскурсий
# 21                                    Автобусные линии
# 147             Изготовление и продажа меховых изделий
# 44                                   Денежные переводы
# 218                Галереи и художественные посредники
# 247  Продажа страхования, гарантированное размещени...
# 246  Продажа страхования, гарантированное размещени...
# 207              Магазины хрусталя и изделий из стекла
# 29   Авиалинии, авиакомпании, нигде более не класси...
# 54   Офисное, фотографическое, фотокопировальное, и...
# 195  Магазины по продаже часов, ювелирных изделий и...
# 219                Галереи и художественные посредники
# 251   Отели, мотели, базы отдыха, сервисы бронирования
# 249             Денежные переводы MasterCard MoneySend
# 203  Магазины кожаных изделий, дорожных принадлежно...
# 278                                 Прокат автомобилей
# 14                      Жилье — отели, мотели, курорты
# 131                                 Продажа мотоциклов
# 154  Оборудование, мебель и бытовые принадлежности ...
# 124                                           Автошины
# 320                   Зубные и медицинские лаборатории
# 64   Оборудование для водопровода и отопительной си...
# 151       Услуги по переделке, починке и пошиву одежды
# 239  Финансовые институты — снятие наличности автом...
# 134  Мужская одежда и аксессуары, включая одежду дл...
# 155  Оборудование, мебель и бытовые принадлежности ...
# 13                      Жилье — отели, мотели, курорты
# 326                        Школы — бизнес и секретарей
# 132                                 Продажа снегоходов
# 78   Химикалии и смежные вещества, не классифициров...
# 194  Магазины по продаже часов, ювелирных изделий и...
# 68   Драгоценные камни и металлы, часы и ювелирные ...
# 161  Различные специализированные магазины бытовых ...
# 123                                           Автошины
# 43                                   Денежные переводы
# 308  Клубы — сельские клубы, членство(спортивный, о...
# 324  Колледжи, университеты, профессиональные школы...
# 328                             Образовательные услуги
# 322  Практикующие врачи, медицинские услуги, нигде ...
# 163                               Бытовое оборудование
# 60                  Электрические части и оборудование
# 325  Колледжи, университеты, профессиональные школы...
# 63   Оборудование для водопровода и отопительной си...
# 315                             Дантисты, ортодонтисты
# 23   Агентства по автотранспортным перевозкам, мест...
# 314                             Дантисты, ортодонтисты
# 160  Различные специализированные магазины бытовых ...
# 281                              СТО общего назначения
# 53   Офисное, фотографическое, фотокопировальное, и...
# 282                              СТО общего назначения
# 86   Товары недлительного пользования, не классифиц...
# 335  Организации, членства, нигде ранее не классифи...
# 101                    Беспошлинные магазины Duty Free
# 79   Химикалии и смежные вещества, не классифициров...
# 238  Финансовые институты — снятие наличности автом...
# 133  Мужская одежда и аксессуары, включая одежду дл...
# 313           Доктора, нигде ранее не классифицируемые
# 93            Розничная продажа стекла, красок и обоев
# 95                           Скобяные товары в розницу
# 215  Прямой маркетинг — другие торговые точки прямо...
# 293                 Театральные продюсерские агентства
# 100                    Беспошлинные магазины Duty Free
# 309  Клубы — сельские клубы, членство(спортивный, о...
# 150                  Магазины мужской и женской одежды
# 317                   Оптика, оптические товары и очки
# 121  Легковой и грузовой транспорт — продажа, серви...
# 162                               Бытовое оборудование
# 323  Практикующие врачи, медицинские услуги, нигде ...
# 164                  Продажа электронного оборудования
# 143  Спортивная одежда, одежда для верховой езды и ...
# 165                  Продажа электронного оборудования
# 340                                  Налоговые платежи
# 11                     Агентства по аренде автомобилей
# 135                             Готовая женская одежда
# 153            Различные магазины одежды и аксессуаров
# 5    Подрядчики, специализированная торговля — нигд...
# 265                                        Иной сервис
# 136                             Готовая женская одежда
# 166  Продажа музыкальных инструментов, фортепиано, нот
# 321                   Зубные и медицинские лаборатории
# 311     Услуги отдыха, нигде ранее не классифицируемые
# 202  Магазины кожаных изделий, дорожных принадлежно...
# 56   Компьютеры, периферийное компьютерное оборудов...

# %%
gb_in_r = pd.merge(gb_in, tr_mcc_codes, on='mcc_code', how='inner')
gb_in_r = gb_in_r.sort_values(by='mean_in',ascending=False)
gb_in_r.head(100)
# Out:
#      mcc_code  gender       mean_in    median_in  \
# 0        3000     0.0  1.186817e+06  1491647.420
# 30       5309     1.0  6.413442e+05   641344.155
# 91       6011     1.0  3.690670e+05   112295.790
# 7        4511     0.0  3.566089e+05    46512.690
# 2        3501     1.0  3.244338e+05   320166.525
# 58       5681     1.0  3.221317e+05   322131.700
# 111      8099     1.0  3.007281e+05   300728.120
# 10       4722     1.0  2.910883e+05   387981.950
# 90       6011     0.0  2.507791e+05   112295.790
# 97       6536     1.0  2.466587e+05   247050.730
# 8        4511     1.0  2.321753e+05   113463.660
# 65       5722     0.0  2.109836e+05   210983.570
# 103      7512     1.0  2.051897e+05   205189.670
# 108      7999     1.0  1.769752e+05   176975.240
# 9        4722     0.0  1.699106e+05   153202.900
# 19       5039     1.0  1.666470e+05   166646.950
# 73       5813     1.0  1.590261e+05   159026.110
# 29       5309     0.0  1.529570e+05    49277.860
# 52       5641     1.0  1.439949e+05   128129.490
# 92       6012     0.0  1.273235e+05    56844.130
# 60       5691     1.0  1.251708e+05   113304.650
# 63       5712     1.0  1.235254e+05   123525.370
# 93       6012     1.0  1.208681e+05    23391.215
# 61       5699     0.0  1.147836e+05    89814.170
# 41       5511     1.0  1.147101e+05   114710.150
# 95       6211     1.0  1.122958e+05   112295.790
# 110      8099     0.0  1.111728e+05   111172.830
# 88       6010     0.0  1.079579e+05    14867.960
# 96       6536     0.0  1.004788e+05    22099.810
# 42       5533     0.0  9.837111e+04    98371.110
# 31       5311     0.0  9.761071e+04    73666.040
# 47       5611     0.0  9.488994e+04    94889.940
# 3        4111     1.0  9.401403e+04    94014.030
# 1        3000     1.0  9.358731e+04    79280.830
# 62       5712     0.0  8.906928e+04    20168.320
# 33       5331     0.0  8.684058e+04    96450.850
# 87       5999     1.0  8.664096e+04    23877.790
# 80       5948     0.0  7.838246e+04    78382.460
# 49       5621     0.0  7.726757e+04    54991.245
# 50       5631     0.0  7.633119e+04    80830.510
# 75       5941     0.0  7.359304e+04    37383.265
# 39       5499     0.0  7.353763e+04    72220.905
# 99       7298     0.0  6.836568e+04    68365.680
# 64       5719     1.0  6.735501e+04    67355.010
# 68       5732     1.0  6.663096e+04    44693.720
# 59       5691     0.0  6.464707e+04    46715.045
# 48       5611     1.0  6.011935e+04    60119.350
# 57       5661     1.0  5.950458e+04    66703.700
# 67       5732     0.0  5.605806e+04    56058.060
# 53       5651     0.0  5.477059e+04    46681.360
# 5        4112     1.0  5.433060e+04    40747.650
# 89       6010     1.0  5.368726e+04    10771.410
# 56       5661     0.0  5.214092e+04    30387.240
# 55       5655     1.0  5.099352e+04    50993.520
# 79       5945     1.0  4.873016e+04    31375.440
# 106      7995     1.0  4.792784e+04    47927.840
# 51       5641     0.0  4.720960e+04    49387.690
# 34       5331     1.0  4.575528e+04    15363.970
# 83       5969     0.0  4.452753e+04    44527.530
# 20       5094     0.0  4.334617e+04    43346.170
# 78       5945     0.0  3.909241e+04    39092.410
# 26       5261     0.0  3.888842e+04    20355.855
# 4        4112     0.0  3.848897e+04    21601.220
# 66       5722     1.0  3.818805e+04    44918.320
# 32       5311     1.0  3.809073e+04    38090.730
# 17       4900     0.0  3.591219e+04    35912.190
# 11       4812     0.0  3.483415e+04    34834.150
# 44       5541     0.0  3.377004e+04    33688.740
# 22       5200     1.0  3.362810e+04    33628.100
# 113      9311     0.0  3.330042e+04    33300.420
# 46       5542     1.0  3.197795e+04    36380.690
# 27       5261     1.0  3.185549e+04    24682.610
# 45       5541     1.0  2.877346e+04    27548.965
# 23       5211     0.0  2.789707e+04    17888.720
# 38       5411     1.0  2.768460e+04    15249.770
# 76       5941     1.0  2.686115e+04    28590.510
# 21       5200     0.0  2.483983e+04    24839.830
# 82       5964     1.0  2.414084e+04     6394.010
# 85       5995     0.0  2.284096e+04    22840.960
# 109      8043     0.0  2.268375e+04    22683.750
# 54       5651     1.0  1.945031e+04    20527.670
# 16       4829     1.0  1.877482e+04     8938.070
# 24       5211     1.0  1.867030e+04    18670.300
# 43       5533     1.0  1.853292e+04    20887.020
# 72       5812     1.0  1.813951e+04    22459.160
# 104      7832     0.0  1.796733e+04    17967.330
# 37       5411     0.0  1.720315e+04     9099.780
# 36       5399     1.0  1.652635e+04    16526.350
# 107      7999     0.0  1.609573e+04    22459.160
# 74       5912     0.0  1.545190e+04    15451.900
# 12       4812     1.0  1.538452e+04    15384.525
# 98       7273     0.0  1.535443e+04    15354.430
# 94       6051     1.0  1.391354e+04    22348.210
# 13       4814     1.0  1.347549e+04    13475.495
# 84       5977     0.0  1.291402e+04    12914.020
# 101      7372     1.0  1.139667e+04    11396.670
# 71       5735     1.0  9.904485e+03     9904.485
# 102      7399     0.0  9.185720e+03     6653.300
# 81       5964     0.0  8.978625e+03     5541.120
# 28       5300     0.0  8.961430e+03     8961.430
#
#                                        mcc_description
# 0                              Авиалинии, авиакомпании
# 30                     Беспошлинные магазины Duty Free
# 91   Финансовые институты — снятие наличности автом...
# 7    Авиалинии, авиакомпании, нигде более не класси...
# 2                       Жилье — отели, мотели, курорты
# 58              Изготовление и продажа меховых изделий
# 111  Практикующие врачи, медицинские услуги, нигде ...
# 10    Туристические агентства и организаторы экскурсий
# 90   Финансовые институты — снятие наличности автом...
# 97              Денежные переводы MasterCard MoneySend
# 8    Авиалинии, авиакомпании, нигде более не класси...
# 65                                Бытовое оборудование
# 103                                 Прокат автомобилей
# 108     Услуги отдыха, нигде ранее не классифицируемые
# 9     Туристические агентства и организаторы экскурсий
# 19   Строительные материалы — нигде более не класси...
# 73   Бары, коктейль-бары, дискотеки, ночные клубы и...
# 29                     Беспошлинные магазины Duty Free
# 52   Детская одежда, включая одежду для самых мален...
# 92            Финансовые институты — торговля и услуги
# 60                   Магазины мужской и женской одежды
# 63   Оборудование, мебель и бытовые принадлежности ...
# 93            Финансовые институты — торговля и услуги
# 61             Различные магазины одежды и аксессуаров
# 41   Легковой и грузовой транспорт — продажа, серви...
# 95                       Ценные бумаги: брокеры/дилеры
# 110  Практикующие врачи, медицинские услуги, нигде ...
# 88    Финансовые институты — снятие наличности вручную
# 96              Денежные переводы MasterCard MoneySend
# 42                           Автозапчасти и аксессуары
# 31                                          Универмаги
# 47   Мужская одежда и аксессуары, включая одежду дл...
# 3    Транспортировка — пригородные и локальные сезо...
# 1                              Авиалинии, авиакомпании
# 62   Оборудование, мебель и бытовые принадлежности ...
# 33                              Универсальные магазины
# 87                  Плавательные бассейны — распродажа
# 80   Магазины кожаных изделий, дорожных принадлежно...
# 49                              Готовая женская одежда
# 50                               Аксессуары для женщин
# 75                               Магазины спорттоваров
# 39   Различные продовольственные магазины — рынки, ...
# 99                                     Центры здоровья
# 64   Различные специализированные магазины бытовых ...
# 68                   Продажа электронного оборудования
# 59                   Магазины мужской и женской одежды
# 48   Мужская одежда и аксессуары, включая одежду дл...
# 57                                    Обувные магазины
# 67                   Продажа электронного оборудования
# 53                               Одежда для всей семьи
# 5                      Пассажирские железные перевозки
# 89    Финансовые институты — снятие наличности вручную
# 56                                    Обувные магазины
# 55   Спортивная одежда, одежда для верховой езды и ...
# 79                                    Магазины игрушек
# 106                       Транзакции по азартным играм
# 51   Детская одежда, включая одежду для самых мален...
# 34                              Универсальные магазины
# 83   Прямой маркетинг — другие торговые точки прямо...
# 20   Драгоценные камни и металлы, часы и ювелирные ...
# 78                                    Магазины игрушек
# 26   Садовые принадлежности (в том числе для ухода ...
# 4                      Пассажирские железные перевозки
# 66                                Бытовое оборудование
# 32                                          Универмаги
# 17   Коммунальные услуги — электричество, газ, сани...
# 11   Телекоммуникационное оборудование, включая про...
# 44                             Станции техобслуживания
# 22                                     Товары для дома
# 113                                  Налоговые платежи
# 46                    Автоматизированные бензозаправки
# 27   Садовые принадлежности (в том числе для ухода ...
# 45                             Станции техобслуживания
# 23                       Лесо- и строительный материал
# 38                   Бакалейные магазины, супермаркеты
# 76                               Магазины спорттоваров
# 21                                     Товары для дома
# 82           Прямой маркетинг — торговля через каталог
# 85                                         Зоомагазины
# 109                   Оптика, оптические товары и очки
# 54                               Одежда для всей семьи
# 16                                   Денежные переводы
# 24                       Лесо- и строительный материал
# 43                           Автозапчасти и аксессуары
# 72              Места общественного питания, рестораны
# 104                                         Кинотеатры
# 37                   Бакалейные магазины, супермаркеты
# 36                  Различные товары общего назначения
# 107     Услуги отдыха, нигде ранее не классифицируемые
# 74                                              Аптеки
# 12   Телекоммуникационное оборудование, включая про...
# 98                                    Службы знакомств
# 94   Не-финансовые институты — иностранная валюта, ...
# 13   Звонки с использованием телефонов, считывающих...
# 84                                  Магазины косметики
# 101  Программирование, обработка данных, интегриров...
# 71                                Магазины звукозаписи
# 102                                      Бизнес-сервис
# 81           Прямой маркетинг — торговля через каталог
# 28                                            Оптовики

# %%
pd.options.display.max_rows = 5
gb_abs_r = pd.merge(gb_abs, tr_mcc_codes, on='mcc_code',  how='inner')
mask = gb_abs_r.index[gb_abs_r['mcc_description']=='Флористика'].tolist()
gb_abs_r.iloc[[226,227]]
# Out:
#      mcc_code  gender   mean_amount  median_amount mcc_description
# 226      5992     0.0  22291.486845       13890.99      Флористика
# 227      5992     1.0  26093.348491       19090.28      Флористика

# %%
gb_abr_r=gb_abs_r.set_index('mcc_description')
gb_abr_r.loc["Бары, коктейль-бары, дискотеки, ночные клубы и таверны — места продажи алкогольных напитков"]
# Out:
#                                                     mcc_code  gender  \
# mcc_description
# Бары, коктейль-бары, дискотеки, ночные клубы и ...      5813     0.0
# Бары, коктейль-бары, дискотеки, ночные клубы и ...      5813     1.0
#
#                                                      mean_amount  \
# mcc_description
# Бары, коктейль-бары, дискотеки, ночные клубы и ...  15601.340943
# Бары, коктейль-бары, дискотеки, ночные клубы и ...  29649.440630
#
#                                                     median_amount
# mcc_description
# Бары, коктейль-бары, дискотеки, ночные клубы и ...       10106.62
# Бары, коктейль-бары, дискотеки, ночные клубы и ...       13475.49

# %%
gb_abr_r.loc["Ценные бумаги: брокеры/дилеры"]
# Out:
#                                mcc_code  gender   mean_amount  median_amount
# mcc_description
# Ценные бумаги: брокеры/дилеры      6211     0.0   6737.750000        6737.75
# Ценные бумаги: брокеры/дилеры      6211     1.0  74039.339308       11229.58

# %% [markdown]
# Ответ: 1, 3, 5

# %% [markdown]
# #### Task 5:
# 1. Разбейте расходы (отрицательные значения сумм) на 5 бакетов amount_bucket равного объёма (с помощью pd.qcut), разбив все траты на категории 'Very High', 'High', 'Middle', 'Low', 'Very Low'. (\*)
# 2. Оставшиеся неотрицательные траты отнесите к категории 'Income'.
# (воспользуйтесь функцией .cat.add_categories('Income') для того, чтобы добавить новую категорию 'Income' к категориям 'Very High', 'High', 'Middle', 'Low', 'Very Low', а затем заполните пустые значения новой категорией).
# 3. Из поля tr_datetime выделите час tr_hour, в который произошла транзакция, как первые 2 цифры до ":". (\**)
# 3. После этого постройте сводную таблицу, значениями в которой является пол gender, индексы - tr_hour, столбцы - amount_bucket.
# 4. Отрисуйте полученные результаты, передав их в функцию plot_pivot_table, расположенную ниже.
# 5. Выберите верные ответы на вопросы ниже.
#
# #### Вопросы:
#     - 1) Ночные поступления денег (01-05 часов) в более чем 85% случаев являются мужскими.
#     - 2) Посмотрев на долю мужчин в поступлениях средств (Income), можно сделать вывод, что количество поступлений средств женщинам в целом больше, чем мужчинам.
#     - 3) Самые низкие траты в 3 часа ночи осуществляются в более 70% случаев женщинами.
#     - 4) Существуют особые часы в мелких тратах, когда женщины тратят намного больше мужчин (>80%)
#     - 5) Посмотрев на долю мужчин в максимальных тратах средств (Very High), можно сделать вывод, что количество высоких трат в каждый возможный час мужчин больше, чем у женщин.
#
# ##### Пояснения:
# (\*) Обратите внимание, что в категории Very High Должны оказаться максимальные по модулю отрицательные транзакции. <br>
# (\**) Например, для строки "0 10:23:26" час будет равен 10, а для строки "6 07:08:31"- 07. Можно воспользоваться функциями str.split() или str.find() и
# функцией .apply(lambda x: x[])

# %%
def plot_pivot_table(pivot_table):
    plt.figure(figsize=(9, 11))
    sns.heatmap(pivot_table, cmap="YlGnBu", annot=True, 
                fmt='.3g', annot_kws={"size": 14, "fontsize": 14})
    plt.xticks(fontsize=15)
    plt.yticks(rotation=0, fontsize=15)
    plt.xlabel('Bucket', size=18)
    plt.ylabel('Hour', fontsize=18)
    plt.title('Gender analysis per bucket and hour', fontsize=20)
    plt.show()

# %%
table5 = table[table.amount < 0]
table5.amount = np.abs(table5.amount)
table5
# Out:
# A:\Anaconda\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#         customer_id   tr_datetime  mcc_code  tr_type    amount term_id  \
# 0          39026145    0 10:23:26      4814     1030   2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030   5614.79     NaN
# ...             ...           ...       ...      ...       ...     ...
# 999565     62693770  333 19:26:37      4900     2320  72385.87  888917
# 999566     62693770  333 19:27:26      4900     2320   4491.83  888917
#
#         gender                                    mcc_description  \
# 0          1.0  Звонки с использованием телефонов, считывающих...
# 1          1.0  Звонки с использованием телефонов, считывающих...
# ...        ...                                                ...
# 999565     0.0  Коммунальные услуги — электричество, газ, сани...
# 999566     0.0  Коммунальные услуги — электричество, газ, сани...
#
#                                         tr_description
# 0                       Оплата услуги. Банкоматы СБ РФ
# 1                       Оплата услуги. Банкоматы СБ РФ
# ...                                                ...
# 999565  Безналичный перевод денежных средств через POS
# 999566  Безналичный перевод денежных средств через POS
#
# [768645 rows x 9 columns]

# %%
table5['amount_cat'], categs = pd.qcut(table5.amount, 5, labels=['Very low','Low','Middle','High','Very high'],
         retbins=True)
table5
# Out:
# <ipython-input-69-a97953afb039>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table5['amount_cat'], categs = pd.qcut(table5.amount, 5, labels=['Very low','Low','Middle','High','Very high'],
#         customer_id   tr_datetime  mcc_code  tr_type    amount term_id  \
# 0          39026145    0 10:23:26      4814     1030   2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030   5614.79     NaN
# ...             ...           ...       ...      ...       ...     ...
# 999565     62693770  333 19:26:37      4900     2320  72385.87  888917
# 999566     62693770  333 19:27:26      4900     2320   4491.83  888917
#
#         gender                                    mcc_description  \
# 0          1.0  Звонки с использованием телефонов, считывающих...
# 1          1.0  Звонки с использованием телефонов, считывающих...
# ...        ...                                                ...
# 999565     0.0  Коммунальные услуги — электричество, газ, сани...
# 999566     0.0  Коммунальные услуги — электричество, газ, сани...
#
#                                         tr_description amount_cat
# 0                       Оплата услуги. Банкоматы СБ РФ   Very low
# 1                       Оплата услуги. Банкоматы СБ РФ        Low
# ...                                                ...        ...
# 999565  Безналичный перевод денежных средств через POS  Very high
# 999566  Безналичный перевод денежных средств через POS        Low
#
# [768645 rows x 10 columns]

# %%
table_cat = table.copy()
table_cat['categ'] = table5.amount_cat
table_cat['categ'] = table_cat.categ.cat.add_categories('Income')
table_cat['categ'] = table_cat.categ.fillna("Income")
table_cat
# Out:
#         customer_id   tr_datetime  mcc_code  tr_type     amount term_id  \
# 0          39026145    0 10:23:26      4814     1030   -2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030   -5614.79     NaN
# ...             ...           ...       ...      ...        ...     ...
# 999582     89619970  104 23:39:35      3000     6000  408307.49     NaN
# 999583     89619970  105 23:38:49      3000     6000  204153.74     NaN
#
#         gender                                    mcc_description  \
# 0          1.0  Звонки с использованием телефонов, считывающих...
# 1          1.0  Звонки с использованием телефонов, считывающих...
# ...        ...                                                ...
# 999582     NaN                            Авиалинии, авиакомпании
# 999583     NaN                            Авиалинии, авиакомпании
#
#                         tr_description     categ
# 0       Оплата услуги. Банкоматы СБ РФ  Very low
# 1       Оплата услуги. Банкоматы СБ РФ       Low
# ...                                ...       ...
# 999582      Возврат  покупки. ТУ СБ РФ    Income
# 999583      Возврат  покупки. ТУ СБ РФ    Income
#
# [999584 rows x 10 columns]

# %%
table_cat['tr_hour']= table_cat.tr_datetime.apply(lambda x: (x.split()[1]).split(':')[0])
table_cat
# Out:
#         customer_id   tr_datetime  mcc_code  tr_type     amount term_id  \
# 0          39026145    0 10:23:26      4814     1030   -2245.92     NaN
# 1          39026145    6 07:08:31      4814     1030   -5614.79     NaN
# ...             ...           ...       ...      ...        ...     ...
# 999582     89619970  104 23:39:35      3000     6000  408307.49     NaN
# 999583     89619970  105 23:38:49      3000     6000  204153.74     NaN
#
#         gender                                    mcc_description  \
# 0          1.0  Звонки с использованием телефонов, считывающих...
# 1          1.0  Звонки с использованием телефонов, считывающих...
# ...        ...                                                ...
# 999582     NaN                            Авиалинии, авиакомпании
# 999583     NaN                            Авиалинии, авиакомпании
#
#                         tr_description     categ tr_hour
# 0       Оплата услуги. Банкоматы СБ РФ  Very low      10
# 1       Оплата услуги. Банкоматы СБ РФ       Low      07
# ...                                ...       ...     ...
# 999582      Возврат  покупки. ТУ СБ РФ    Income      23
# 999583      Возврат  покупки. ТУ СБ РФ    Income      23
#
# [999584 rows x 11 columns]

# %%
pivot = table_cat.pivot_table(['gender'], index=['tr_hour'], columns='categ')
plot_pivot_table(pivot)

# %% [markdown]
# Ответ: 1, 3, 5

# %% [markdown]
# #### Task 6:
# 1. Измените тип поля tr_day на int.
# 2. Выберите из transactions все MCC коды, которые встретились в выборке более чем 60000 раз.
# 3. Сгруппируйте отфильтрованный датафрейм по дню и MCC-коду, получая средние значения суммы amount.
# 4. Далее отрисуйте зависимость средних сумм (может пригодится метод unstack()) по каждому из MCC-кодов по дням.
# 5. Выберите верные ответы на вопросы ниже.
#
# #### Вопросы:
#     - 1) 2 из полученных MCC-кодов связаны с финансовыми институтами
#     - 2) 2 MCC кода, связанные со снятием наличности имеют в целом разные знаки (в одном случае почти везде - траты, в другом - пополнения)
#     - 3) Бакалейные магазины обладают максимальными средними тратами среди выбранных MCC-кодов
#     - 4) Денежные переводы имеют как минимум 3 явных минимума средних
#     - 5) Категория "Звонки с использованием телефонов, считывающих магнитную ленту" имеет визуально очень большую дисперсию.

# %%
date_split=table.tr_datetime.str.split(n=1,expand=True)
day = table.copy()
day["tr_day"] = date[0]
day["tr_day"]=day["tr_day"].astype('int64')

f = lambda x: x.tr_datetime.count() > 60000
gb = day.groupby('mcc_code').filter(f)
gb = gb.groupby(['tr_day','mcc_code']).amount.agg(mean_amount=np.mean)
gb = gb.reset_index()
gb_desc = pd.merge(gb,  tr_mcc_codes, on='mcc_code', how='inner')
gb_desc = gb_desc.drop(columns=['mcc_code'])
gb_desc = gb_desc.set_index(['tr_day','mcc_description'])
gb_desc = gb_desc.unstack(level = 1)
gb_desc = gb_desc.reset_index()
gb_desc = gb_desc.set_index('tr_day')
gb_desc
# Out:
#                                       mean_amount                    \
# mcc_description Бакалейные магазины, супермаркеты Денежные переводы
# tr_day
# 0                                   -15462.567344    -214754.866266
# 1                                   -17770.243543    -158317.573750
# ...                                           ...               ...
# 455                                 -12953.262927    -243267.887869
# 456                                 -15411.548528    -274049.766409
#
#                                                                                 \
# mcc_description Звонки с использованием телефонов, считывающих магнитную ленту
# tr_day
# 0                                                     -5631.316489
# 1                                                     -6375.587685
# ...                                                                        ...
# 455                                                   -5007.255934
# 456                                                   -5945.182500
#
#                                                                         \
# mcc_description Финансовые институты — снятие наличности автоматически
# tr_day
# 0                                                    -55388.115175
# 1                                                    -38938.920557
# ...                                                                ...
# 455                                                  -16193.186198
# 456                                                   18406.478780
#
#
# mcc_description Финансовые институты — снятие наличности вручную
# tr_day
# 0                                                   90390.672987
# 1                                                   57658.709639
# ...                                                          ...
# 455                                                100973.037396
# 456                                                109925.614017
#
# [457 rows x 5 columns]

# %%
gb_desc.plot(figsize=(20, 15))

# %% [markdown]
# Ответ: 1, 2, 4
